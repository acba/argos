# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/workspace/fiscalizacao_auditoria_si/02-gera_achados/'

# %%
# !pip install python-docx

# %%
import os
import re
import copy
import pickle
import pandas as pd
from docx import Document
import sys

# Adiciona o caminho absoluto de "outra_pasta" ao sys.path
sys.path.append(os.path.abspath('../00-utils'))

from utils import avalia_expressao
from classes import FonteInformacao, Achado, AcaoVerificacao, ProcedimentoAuditoria, Auditado, \
    gerar_tabela_encaminhamentos, gerar_tabela_achados, gerar_tabela_situacoes_inconformes

pd.set_option('display.max_colwidth', None)

if not os.path.exists('resultado/relatorios'):
    os.makedirs('resultado/relatorios')

# %%
df_jurisdicionados   = pd.read_excel('../00-dados/bd_jurisdicionados.xlsx').applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_procedimentos     = pd.read_excel('mapa-verificacao-achados.xlsx', sheet_name='Procedimentos de Auditoria', skiprows=2).applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_acoes_verificacao = pd.read_excel('mapa-verificacao-achados.xlsx', sheet_name='Ações de Verificação', skiprows=2).applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_fontes            = pd.read_excel('mapa-verificacao-achados.xlsx', sheet_name='Fontes de Informação', skiprows=2).applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\augustocba\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# Leitura e criação dos objetos a partir das planilhas

# 1. Leitura das fontes de informação
fontes = {}
for _, row in df_fontes.iterrows():
    fonte = FonteInformacao(
        descricao=row['descricao'],
        filepath=row['filepath'],
        chave_jurisdicionado=row['chave_jurisdicionado'],
        id=row['id']
    )
    fontes[fonte.id] = fonte  # Armazena no dicionário para referência posterior

# 2. Leitura das ações de verificação
acoes = {}
for _, row in df_acoes_verificacao.iterrows():
    fonte_informacao = fontes.get(row['id_fonte_informacao'])

    acao = AcaoVerificacao(
        fonte_informacao=fonte_informacao,
        informacao_requerida=row['informacao_requerida'],

        acao_exclusiva_auditados=row['acao_exclusiva_auditados'],
        criterio=row['criterio'],
        descricao_situacao_inconforme=row['descricao_situacao_inconforme'],

        descricao_evidencia=row['descricao_evidencia'],
        situacao_inconforme=row['situacao_inconforme'],
        situacao_encontrada_nan_e_achado=row['situacao_encontrada_nan_e_achado'],
        tipo_encaminhamento=row['tipo_encaminhamento'],
        encaminhamento=row['encaminhamento'],
        pre_encaminhamento=row['pre_encaminhamento'],
        auditado_inexistente_e_achado=row['auditado_inexistente_e_achado'],
        descricao_auditado_inexistente=row['descricao_auditado_inexistente'],
        id=row['id']
    )
    acoes[acao.id] = acao  # Armazena no dicionário para referência posterior

# 3. Leitura dos procedimentos de auditoria
procedimentos = {}
for _, row in df_procedimentos.iterrows():
    procedimento = ProcedimentoAuditoria(
        descricao=row['descricao'],
        logica_achado=row['logica_achado'],
        numero_achado=row['numero_achado'],
        nome_achado=row['nome_achado'],
        id=row['id']
    )

    # Adiciona as ações de verificação relevantes que constam na lógica
    acao_ids = re.split(r'[\&\|\~\(\)\s]+', procedimento.logica_achado.replace("(", "").replace(")", ""))
    acao_ids = [acao_id for acao_id in acao_ids if acao_id]

    for acao_id in acao_ids:
        acao = acoes.get(acao_id.strip())
        if acao:
            procedimento.adicionar_acao(acao)
    procedimentos[procedimento.id] = procedimento

# 4. Leitura dos auditados
auditados = {}
for _, row in df_jurisdicionados.iterrows():
    auditado = Auditado(
        nome=row['orgao'],
        sigla=row['sigla'],
        # id=row['id']
    )
    auditados[auditado.sigla] = auditado

# %%
from IPython.display import Markdown

for auditado in auditados.values():    
    print(f'Auditando {auditado.sigla}')
    auditado.aplicar_procedimentos(procedimentos.values(), debug=False)
    auditado.documenta_procedimentos()
    
    if auditado.tem_achados:
        for p in auditado.procedimentos_executados:
            if p.achado:
                print(f'Achado {p.achado.numero}: {p.achado.nome}')

        # display(Markdown(auditado.reporta_procedimentos()))
        # break
    else:
        print('Sem achados!')
    print()
    
    # display(Markdown(auditado.reporta_procedimentos()))
    # break


tabela_encaminhamentos = gerar_tabela_encaminhamentos(auditados, procedimentos)
tabela_encaminhamentos.T.to_excel('resultado/tabela_encaminhamentos_por_auditados.xlsx')

tabela_achados = gerar_tabela_achados(auditados, procedimentos)
tabela_achados.T.to_excel('resultado/tabela_achados_por_auditados.xlsx')

tabela_situacoes = gerar_tabela_situacoes_inconformes(auditados, procedimentos)
tabela_situacoes.T.to_excel('resultado/tabela_situacoes_inconformes_por_auditados.xlsx')
# Out:
# Auditando AGENERSA
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando AGERIO
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando AGETRANSP
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando ALERJ
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando CGE
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando DEGASE
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando DETRAN
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando DPGE
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando FAETEC
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando FAPERJ
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando FIA
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando FS
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando GSI
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando INEA
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando ISP
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando JUCERJA
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando MPRJ
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando PGE
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando PROCON
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando PRODERJ
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando RIOPREVIDENCIA
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando RJPREV
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
#
# Auditando SEAP
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SECC
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEDEC
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEDSODH
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEEDUC
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEFAZ
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEPLAG
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEPOL
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SEPM
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SES
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando SETD
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando TCERJ
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando TJRJ
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso
#
# Auditando UERJ
# Achado 1: Ausência de uma estrutura básica atuante de segurança da informação que estabeleça papéis, políticas e responsabilidades
# Achado 2: Medidas básicas de segurança cibernética insuficientes na gestão ativa dos ativos corporativos e softwares
# Achado 3: Medidas básicas de segurança cibernética insuficientes na proteção dos dados da organização
# Achado 4: Medidas básicas de segurança cibernética insuficientes no estabelecimento de configuração segura dos ativos da organização
# Achado 5: Medidas básicas de segurança cibernética insuficientes na gestão de contas e de controle de acesso

# %%
def gerar_tabela_acoesverificacao(auditados, procedimentos):
    # Coleta todos os encaminhamentos únicos
    todas_acoes = []
    for p in procedimentos.values():
        for acao in p.acoes_verificacao:
            # texto = f"[ACHADO {p.numero_achado}] {acao.informacao_requerida}"
            texto = f"[ACHADO {p.numero_achado}] {acao.informacao_requerida}"
            if texto not in todas_acoes:
                todas_acoes.append(texto)
            
    # Inicializa uma lista para armazenar os dados da tabela
    dados_tabela = []

    for auditado in auditados.values():        
        if auditado.foi_auditado:
            acoes_info_auditado = []
            for p in auditado.procedimentos_executados:
                if p.achado is not None: # Se tem achado
                    for av in p.acoes_verificacao:
                        if av.resultado:
                            acoes_info_auditado.append(f"[ACHADO {p.numero_achado}] {av.informacao_requerida}")
                            # print(av)
            
            # print(acoes_info_auditado)
            
            linha = {f"{acaov}": ('X' if any([av == acaov for av in acoes_info_auditado]) else '') for acaov in todas_acoes}

            linha["Auditado"] = auditado.sigla  # Adiciona o identificador do auditado
            dados_tabela.append(linha)
        else:
            print(f'{auditado.sigla} ainda não foi auditado')
            

    # Cria o DataFrame com os dados coletados
    df_situacoes = pd.DataFrame(dados_tabela)
    df_situacoes = df_situacoes.set_index("Auditado")

    return df_situacoes


tbl_av = gerar_tabela_acoesverificacao(auditados, procedimentos)
tbl_av.T.to_excel('resultado/tabela_itens_por_auditado.xlsx')
tbl_av.head()
# Out:
#           [ACHADO 1] q0002 [ACHADO 1] q0002ext[C] [ACHADO 1] q0003  \
# Auditado
# AGENERSA                                                         X
# AGERIO
# AGETRANSP                X                                       X
# ALERJ                    X
# CGE                      X
#
#           [ACHADO 1] q0004 [ACHADO 1] q0004ext[A] [ACHADO 1] q0004ext[B]  \
# Auditado
# AGENERSA
# AGERIO
# AGETRANSP                X
# ALERJ                    X
# CGE                      X
#
#           [ACHADO 1] q0004ext[C] [ACHADO 1] q0004ext[F] [ACHADO 2] q0101  \
# Auditado
# AGENERSA
# AGERIO
# AGETRANSP
# ALERJ                                                                  X
# CGE                                                                    X
#
#           [ACHADO 2] q0101ext[A]  ... [ACHADO 5] q0504ext[C] [ACHADO 5] q0601  \
# Auditado                          ...
# AGENERSA                          ...
# AGERIO                            ...
# AGETRANSP                         ...
# ALERJ                          X  ...
# CGE                               ...
#
#           [ACHADO 5] q0601ext[A] [ACHADO 5] q0602 [ACHADO 5] q0602ext[A]  \
# Auditado
# AGENERSA
# AGERIO
# AGETRANSP                                       X
# ALERJ
# CGE
#
#           [ACHADO 5] q0602ext[D] [ACHADO 5] q0603 [ACHADO 5] q0603ext[A]  \
# Auditado
# AGENERSA                                                               X
# AGERIO
# AGETRANSP                                       X
# ALERJ
# CGE                            X                X
#
#           [ACHADO 5] q0603ext[B] [ACHADO 5] q0603ext[C]
# Auditado
# AGENERSA                                              X
# AGERIO
# AGETRANSP
# ALERJ                          X                      X
# CGE
#
# [5 rows x 106 columns]

# %%
# Função para criar a expressão combinada
def criar_condicao(row):
    # Seleciona as colunas com 'X'
    entidades = row[row == 'X'].index.tolist()
    qtd_igual = len(entidades)
    qtd_diferente = 36 - qtd_igual

    condicao = '=='
    if qtd_diferente < qtd_igual:
        condicao = '!='
        entidades = row[row != 'X'].index.tolist()
            
    # Cria a expressão OR
    if entidades:
        if condicao == '==':
            return ' OR '.join([f'TOKEN:FIRSTNAME == "{ent}"' for ent in entidades])
        else:
            return ' AND '.join([f'TOKEN:FIRSTNAME != "{ent}"' for ent in entidades])
    return ''

# Aplica a função a cada linha do DataFrame original
df_condicoes = tabela_situacoes.T.apply(criar_condicao, axis=1)
df_situacoes_logica = pd.DataFrame(df_condicoes, columns=['CONDICAO'])

df_situacoes_logica.to_excel('resultado/20241209_tabela_situacoes_inconformes_por_auditados_logica.xlsx')

# %%
with open("resultado/auditados.pkl", "wb") as f:
    pickle.dump(auditados, f)

# %%
auditados['AGENERSA'].get_plano_acao()
# Out:
# [{'achado_num': 1,
#   'encaminhamento': 'estabeleça um processo de gestão de riscos alinhado ao contexto organizacional para identificar, avaliar e tratar os riscos de segurança da informação',
#   'tipo': 'Determinação'},
#  {'achado_num': 2,
#   'encaminhamento': 'adote integralmente a medida de segurança 1.1 (Estabelecer e manter um inventário detalhado de ativos corporativos) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um inventário preciso, detalhado e atualizado de todos os ativos corporativos conectados à infraestrutura física, virtual ou remotamente',
#   'tipo': 'Recomendação'},
#  {'achado_num': 2,
#   'encaminhamento': 'adote integralmente a medida de segurança 1.2 (Endereçar ativos não autorizados) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer um processo para lidar com ativos não autorizados com periodicidade semanal e que trate adequadamente os ativos não autorizados identificados',
#   'tipo': 'Recomendação'},
#  {'achado_num': 2,
#   'encaminhamento': 'adote integralmente a medida de segurança 2.1 (Estabelecer e manter um inventário de software) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um inventário preciso, detalhado e atualizado dos softwares instalados nos ativos corporativos',
#   'tipo': 'Recomendação'},
#  {'achado_num': 2,
#   'encaminhamento': 'adote integralmente a medida de segurança 2.2 (Assegurar que o software autorizado seja atualmente suportado) prevista nos Controles CIS v8, atentando-se, minimamente, em revisar mensalmente os softwares autorizados do inventário afim de verificar se eles ainda possuem suporte',
#   'tipo': 'Recomendação'},
#  {'achado_num': 2,
#   'encaminhamento': 'adote integralmente a medida de segurança 2.3 (Endereçar o software não autorizado) prevista nos Controles CIS v8, atentando-se, minimamente, em revisar mensalmente os softwares instalados nos ativos corporativos, a fim de remover os softwares não autorizados identificados',
#   'tipo': 'Recomendação'},
#  {'achado_num': 3,
#   'encaminhamento': 'adote integralmente a medida de segurança 3.1 (Estabelecer e manter um processo de gestão de dados) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um processo de gestão de dados que trate a sensibilidade dos dados, o proprietário dos dados, o tratamento dos dados, os limites de retenção de dados e os requisitos de descarte, conforme as políticas definidas pela organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 3,
#   'encaminhamento': 'adote integralmente a medida de segurança 3.2 (Estabelecer e manter um inventário de dados) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um inventário de dados sensíveis, com base no processo de gestão de dados da organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 3,
#   'encaminhamento': 'adote integralmente a medida de segurança 3.4 (Aplicar retenção de dados) prevista nos Controles CIS v8, atentando-se, minimamente, com a definição de limites máximos e mínimos para a retenção dos dados, assegurando que essa retenção seja realizada em conformidade com o processo de gestão de dados da organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 3,
#   'encaminhamento': 'adote integralmente a medida de segurança 3.5 (Descartar dados com segurança) prevista nos Controles CIS v8, atentando-se, minimamente, em descartar os dados com segurança conforme descrito no processo de gestão de dados da organização, certificando-se que o processo e o método de descarte sejam adequados com a sensibilidade dos dados',
#   'tipo': 'Recomendação'},
#  {'achado_num': 3,
#   'encaminhamento': 'adote integralmente a medida de segurança 3.6 (Criptografar dados em dispositivos de usuário final) prevista nos Controles CIS v8, atentando-se, minimamente, em criptografar os dados nos dispositivos de usuário final que contenham dados sensíveis',
#   'tipo': 'Recomendação'},
#  {'achado_num': 4,
#   'encaminhamento': 'adote integralmente as medidas de segurança 4.1 (Estabelecer e manter um processo de configuração segura) e 4.2 (Estabelecer e Manter um Processo de Configuração Segura para a\nInfraestrutura de Rede) previstas nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um processo de configuração segura para ativos corporativos, softwares e dispositivos de rede da organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 4,
#   'encaminhamento': 'adote integralmente a medida de segurança 4.3 (Configurar o bloqueio automático de sessão nos ativos corporativos) prevista nos Controles CIS v8, atentando-se, minimamente, em configurar nos ativos corporativos o bloqueio automático de sessão após um período de inatividade que para os sistemas operacionais não devem exceder 15 minutos e para os dispositivos móveis não devem exceder 2 minutos',
#   'tipo': 'Recomendação'},
#  {'achado_num': 4,
#   'encaminhamento': 'adote integralmente as medidas de segurança 4.4 (Implementar e gerenciar um firewall nos servidores) e 4.5 (Implementar e gerenciar um firewall nos dispositivos de usuário final) previstas nos Controles CIS v8, atentando-se, minimamente, em implementar e gerenciar firewalls nos servidores e nos dispositivos de usuários finais',
#   'tipo': 'Recomendação'},
#  {'achado_num': 4,
#   'encaminhamento': 'adote integralmente a medida de segurança 4.6 (Gerenciar com segurança os ativos e software corporativos) prevista nos Controles CIS v8, atentando-se, minimamente, em gerenciar seguramente os ativos corporativos e softwares da organização por meio da utilização de protocolos seguros',
#   'tipo': 'Recomendação'},
#  {'achado_num': 4,
#   'encaminhamento': 'adote integralmente a medida de segurança 4.7 (Gerenciar contas padrão nos ativos e software corporativos) prevista nos Controles CIS v8, atentando-se, minimamente, em gerenciar as contas padrão de administrador e as pré-configuradas pelos fabricantes dos ativos e softwares corporativos da organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente a medida de segurança 5.1 (Estabelecer e manter um inventário de contas) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer, manter e revisar periodicamente um inventário preciso, detalhado e atualizado de todas as contas gerenciadas na organização',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente a medida de segurança 5.2 (Usar senhas exclusivas) prevista nos Controles CIS v8, atentando-se, minimamente, em assegurar o uso de senhas exclusivas para todos os ativos corporativos, garantindo um tamanho mínimo de 8 caracteres às contas que usem MFA e 14 caracteres às contas que não o utilizem',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente a medida de segurança 5.3 (Desabilitar contas inativas) prevista nos Controles CIS v8, atentando-se, minimamente, em excluir ou desabilitar as contas inativas após um período de 45 dias de inatividade',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente a medida de segurança 6.1 (Estabelecer um Processo de Concessão de Acesso) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer um processo, preferencialmente automatizado, para concessão de acesso aos ativos corporativos nos casos de nova contratação, concessão de direitos ou mudança de função',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente a medida de segurança 6.2 (Estabelecer um Processo de Revogação de Acesso) prevista nos Controles CIS v8, atentando-se, minimamente, em estabelecer um processo, preferencialmente automatizado, para a concessão de acesso aos ativos corporativos em casos de nova contratação, concessão de direitos ou mudança de função',
#   'tipo': 'Recomendação'},
#  {'achado_num': 5,
#   'encaminhamento': 'adote integralmente as medidas de segurança 6.3 (Exigir MFA para aplicações expostas externamente), 6.4 (Exigir MFA para acesso remoto à rede) e 6.5 (Exigir MFA para acesso administrativo) previstas nos Controles CIS v8, atentando-se, minimamente, em exigir, onde houve suporte, a utilização de MFA para acesso às aplicações corporativas expostas externamente, à rede e às contas de acesso administrativo',
#   'tipo': 'Recomendação'}]
